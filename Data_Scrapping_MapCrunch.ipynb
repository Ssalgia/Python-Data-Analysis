# %% [markdown]
# <a href="https://colab.research.google.com/github/Ssalgia/Python-Data-Analysis/blob/master/Data_Scrapping_MapCrunch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is Web Scraping?**
#
# Web Scraping (also termed as Scraping, Data Extraction, Data Harvesting, etc.) is a technique used to extract data from the websites. Sometimes web scraping can be very useful wherein we can get the data that we are looking for straight from the web, but sometimes it a bad way to do it, because it’s like stealing the precious data from the website without their permission, but limit your scraping process to once or twice so that this can avoid you from falling in trouble.

# %% [markdown]
# **1. Importing Required Libraries**

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **2.Getting the URL and storing it in a variable.**

# %%
url = 'https://www.mapcrunch.com/'

# %% [markdown]
# **3.Making a request to the website using the requests library.**

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %% [markdown]
# **4.Using the Beautiful Soup library to get the HTML (raw) data from the website**

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %% [markdown]
# **5.Print Soup**

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <title>
#    MapCrunch - Random Street View
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Teleport to a random point on the globe. Find new and exciting travel destinations. Share weird and wonderful places with your friends." name="description"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1,user-scalable=no" name="viewport"/>
#   <meta content="248807751815810" property="fb:app_id"/>
#   <meta content="photo" name="twitter:card"/>
#   <meta content="@mapcrunch" name="twitter:site"/>
#   <meta content="MapCrunch - Random Street View" property="og:title"/>
#   <meta content="http://www.mapcrunch.com" property="og:url"/>
#   <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# **6.Using soup.findAll method to get the respected tag that we are looking for.**

# %%
proftags = soup.findAll("span", { "class" : "button-sprite" })
proftags
# Out:
# [<span class="button-sprite" id="go-sprite"></span>,
#  <span class="button-sprite" id="options-sprite"></span>,
#  <span class="button-sprite" id="map-sprite"></span>]

# %% [markdown]
# **7.Removing all the HTML tags and converting it to a plain text format.**

# %%
for mytag in proftags:
  print(mytag.get_text())

# %% [markdown]
# **8.Here are some simple ways to navigate that data structure**

# %%
soup.title
# Out:
# <title>MapCrunch - Random Street View</title>

# %%
soup.title.string
# Out:
# 'MapCrunch - Random Street View'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.a
# Out:
# <a href="/" id="home-link" title="Home"><i class="fa fa-home fa-fw"></i><span>Home</span></a>

# %%
soup.find_all('a')
# Out:
# [<a href="/" id="home-link" title="Home"><i class="fa fa-home fa-fw"></i><span>Home</span></a>,
#  <a data-tip="Visit the Gallery for a collection of the best Street Views" href="/gallery" id="gallery-link" title="Gallery"><i class="fa fa-picture-o fa-fw" style="margin-right:2px;"></i><span>Gallery</span></a>,
#  <a href="javascript:void(0)" id="about-link" title="About"><i class="fa fa-question-circle fa-fw"></i><span>About</span></a>,
#  <a href="https://random.earth/?m" target="_BLANK" title="Random Google Earth">Random Google Earth!
#           <i class="fa fa-external-link fa-fw"></i></a>,
#  <a class="share" href="http://www.facebook.com/MapCrunch" id="share-fb-menu" target="_BLANK" title="Visit our Facebook Page"></a>,
#  <a class="share" href="http://www.twitter.com/mapcrunch" id="share-twitter-menu" target="_BLANK" title="Follow us on Twitter"></a>,
# ...

# %% [markdown]
# **I wansn't able to figure out why is javascript :void(0) printed alongwith the output. Generally it doesn't happen.**

# %%
for link in soup.find_all('a'):         #extracting all the URLs found within a page’s <a> tags
    print(link.get('href'))
# Out:
# /
# /gallery
# javascript:void(0)
# https://random.earth/?m
# http://www.facebook.com/MapCrunch
# http://www.twitter.com/mapcrunch
# //plus.google.com/112780332075669877333?prsrc=3
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# ...

# %%
print(soup.get_text())           #extracting all the text from a page
# Out:
# MapCrunch - Random Street View
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    html,body {height:100%;overflow:hidden;}
#    body {background-color:#181818;}
#
#
#
#    window.isChrome = 0;
#    window._rr = 0;
#    window.browserVersion = Array;
#    window.isFirefox = typeof InstallTrigger !== 'undefined';
#    window.disMon = false;
#
#
#
#
#
#
#
#
# var _gaq = _gaq || [];
#
# google_ad_client = "ca-pub-4910046262930409";
#
# var isTouch = !!('ontouchstart' in window);
# console.warn = function(){};
#
#   _gaq.push(['_setAccount', 'UA-12857712-5']);
#   _gaq.push(['_trackPageview']);
#
#
# var initString = "64.927334_-23.306448_204.73_-2.4_0";
# var initPanoId = "0NjHzGQTy2yvoUjp0B6Zhw";
# var gPermLink = "http://www.mapcrunch.com/s/789114_64c915d4";
# var jsDate = "Jun 05 2020 00:00:00";
# ...
